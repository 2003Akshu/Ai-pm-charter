# %%
# !pip install weasyprint docx graphviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 54.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.1/849.1 kB 37.2 MB/s eta 0:00:00
# ...
#   Created wheel for docx: filename=docx-0.2.4-py3-none-any.whl size=53892 sha256=4933df3b6d01f99d2c66b8e9b2883a2b3ad30d7a0b1e50f85d6fac502b3dfa95
#   Stored in directory: /root/.cache/pip/wheels/81/f5/1d/e09ba2c1907a43a4146d1189ae4733ca1a3bfe27ee39507767
# Successfully built docx
# ...

# %%
# !pip install WeasyPrint

# %%
import weasyprint

# Define the HTML content with proper formatting
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <style>
        /* Body styling */
        body {
            font-family: Arial, sans-serif;
            margin: 20px;
            background-color: #f4f4f9;
        }

        /* Header styling */
        .header {
            text-align: center;
            background-color: #4CAF50;
            color: white;
            padding: 15px;
        }

        /* Section styling (for each project section) */
        .section {
            background-color: #ffffff;
            border: 2px solid #ddd;
            padding: 15px;
            margin: 10px 0;
            border-radius: 8px;
        }

        /* Section heading styling */
        .section h3 {
            color: #4CAF50;
            font-weight: bold;
            font-size: 18px;
            margin-bottom: 10px;
            border-bottom: 2px solid #4CAF50;
            padding-bottom: 5px;
        }

        /* Paragraph style */
        p {
            font-size: 14px;
            line-height: 1.6;
        }

        /* Table styling */
        .table {
            width: 100%;
            border-collapse: collapse;
            margin: 15px 0;
        }

        .table th, .table td {
            padding: 10px;
            border: 1px solid #ddd;
            text-align: left;
        }

        .table th {
            background-color: #4CAF50;
            color: white;
        }

        /* Bold text for important points */
        .bold {
            font-weight: bold;
        }

        /* Footer styling */
        .footer {
            text-align: center;
            padding: 10px;
            background-color: #4CAF50;
            color: white;
        }

        /* List styling */
        ul {
            font-size: 14px;
        }

        ul li {
            margin-bottom: 5px;
        }

        /* Boxes with heading colors */
        .box {
            background-color: #f1f1f1;
            border: 1px solid #ccc;
            padding: 15px;
            border-radius: 8px;
            margin-bottom: 15px;
        }

        .box h3 {
            background-color: #4CAF50;
            color: white;
            padding: 10px;
            margin: -15px -15px 10px -15px;
            font-size: 16px;
            border-radius: 8px 8px 0 0;
        }
    </style>
    <title>Project Charter: AI Project Management</title>
</head>
<body>

    <!-- Header Section: Project Title -->
    <div class="header">
        <h1>AI Project Management </h1>
        <h2>Project Charter</h2>
    </div>

    <!-- Project Overview Section -->
    <div class="section box">
        <h3>Project Overview</h3>
        <p><span class="bold">Project Name:</span> AI Enhancement Project</p>
        <p><span class="bold">Project Start/End (projected):</span> Jan 2024 - Dec 2024</p>
        <p><span class="bold">Authorization Date:</span> Jan 1, 2024</p>
    </div>

    <!-- Business Case and Project Objectives Section -->
    <div class="section box">
        <h3>Business Case and Project Objectives</h3>
        <p><span class="bold">Problem Statement:</span> Improve AI efficiency for client services.</p>
        <p><span class="bold">Goals and Objectives:</span> Enhance AI algorithms, reduce response time by 30%.</p>
        <p><span class="bold">Expected Benefits:</span> Faster processing, improved customer satisfaction.</p>
        <p><span class="bold">Strategic Alignment:</span> Aligns with organizational goals to enhance digital transformation.</p>
    </div>

    <!-- Stakeholder Information Section -->
    <div class="section box">
        <h3>Stakeholder Information</h3>
        <p><span class="bold">Stakeholder Register:</span> John Doe (Project Manager), Jane Smith (Lead Developer)</p>
        <p><span class="bold">Roles and Responsibilities:</span> John is overseeing the project, Jane is handling the AI development.</p>
        <p><span class="bold">Communication Preferences:</span> Weekly meetings via Zoom, Email for daily updates.</p>
    </div>

    <!-- Project Scope Section -->
    <div class="section box">
        <h3>Project Scope</h3>
        <p><span class="bold">Scope Statement:</span> Develop AI tools for data analysis and customer service.</p>
        <p><span class="bold">Deliverables:</span> AI system, Training materials.</p>
        <p><span class="bold">Boundaries and Constraints:</span> Limited budget, 12-month timeline.</p>
    </div>

    <!-- Risk Assessment Section -->
    <div class="section box">
        <h3>Risk Assessment</h3>
        <table class="table">
            <tr>
                <th>Risk Description</th>
                <th>Mitigation Strategy</th>
                <th>Risk Owner</th>
            </tr>
            <tr>
                <td>Data Loss during processing phase</td>
                <td>Implement regular backups and disaster recovery plans.</td>
                <td>John Doe</td>
            </tr>
            <tr>
                <td>Potential system failure during deployment</td>
                <td>Conduct extensive testing before deployment.</td>
                <td>Jane Smith</td>
            </tr>
        </table>
    </div>

    <!-- Methodology and Tools Section -->
    <div class="section box">
        <h3>Methodology and Tools</h3>
        <p><span class="bold">Selected Project Management Methodology:</span> Agile Scrum</p>
        <p><span class="bold">Tools:</span> Jira, GitHub, Slack</p>
        <p><span class="bold">Reporting Format and Frequency:</span> Weekly progress reports, bi-weekly sprint reviews</p>
    </div>

    <!-- Resources Section -->
    <div class="section box">
        <h3>Resources</h3>
        <p><span class="bold">Human Resources:</span> Project Manager (John Doe), Lead Developer (Jane Smith), AI Team</p>
        <p><span class="bold">Physical Resources:</span> AI Development Workstations, Cloud Infrastructure</p>
        <p><span class="bold">Budgetary Information:</span> Estimated project budget is $500,000 for the year.</p>
    </div>

    <!-- Timeline and Deadlines Section -->
    <div class="section box">
        <h3>Timeline and Deadlines</h3>
        <p><span class="bold">High-Level Project Schedule:</span>
            <ul>
                <li>Jan 2024: Project initiation and setup</li>
                <li>Feb 2024 - Jul 2024: Development and testing</li>
                <li>Aug 2024: Final testing and deployment</li>
                <li>Dec 2024: Project closure</li>
            </ul>
        </p>
        <p><span class="bold">Key Dates and Deliverables:</span>
            <ul>
                <li>End of Q1: Initial AI model completed</li>
                <li>End of Q2: Testing phase completed</li>
                <li>End of Q3: Final AI system ready for deployment</li>
                <li>End of Q4: Project closure report</li>
            </ul>
        </p>
    </div>

    <!-- Approval and Governance Section -->
    <div class="section box">
        <h3>Approval and Governance</h3>
        <p><span class="bold">Project Charter Approval:</span> Signed by John Doe, Jan 2024</p>
        <p><span class="bold">Executive Sponsor Sign-Off:</span> Jane Smith, Jan 2024</p>
        <p><span class="bold">Governance Model:</span> Agile Governance Model with weekly steering committee reviews</p>
    </div>

    <!-- Footer Section -->
    <div class="footer">
        <p>AI Project Management</p>
    </div>

</body>
</html>
"""

# Generate the PDF using WeasyPrint
weasyprint.HTML(string=html_content).write_pdf("/content/AI_Enhancement_Project_Charter_Optimized.pdf")

# Provide the download link for the generated PDF
"/content/AI_Enhancement_Project_Charter_Optimized.pdf"
# Out:
# DEBUG:fontTools.ttLib.ttFont:Reading 'maxp' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'maxp' table
# DEBUG:fontTools.subset.timer:Took 0.007s to load 'maxp'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'maxp'
# INFO:fontTools.subset:maxp pruned
# DEBUG:fontTools.ttLib.ttFont:Reading 'cmap' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'cmap' table
# DEBUG:fontTools.ttLib.ttFont:Reading 'post' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'post' table
# DEBUG:fontTools.subset.timer:Took 0.010s to load 'cmap'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'cmap'
# INFO:fontTools.subset:cmap pruned
# INFO:fontTools.subset:fpgm dropped
# INFO:fontTools.subset:prep dropped
# INFO:fontTools.subset:cvt  dropped
# INFO:fontTools.subset:kern dropped
# DEBUG:fontTools.subset.timer:Took 0.000s to load 'post'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'post'
# INFO:fontTools.subset:post pruned
# INFO:fontTools.subset:GPOS dropped
# ...

# %%
import weasyprint

# HTML content for the project charter
html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <style>
        body { font-family: Arial, sans-serif; margin: 20px; background-color: #f4f4f9; }
        .header, .footer { text-align: center; background-color: #4CAF50; color: white; padding: 15px; }
        .section { background: #fff; border: 2px solid #ddd; padding: 15px; margin: 10px 0; border-radius: 8px; }
        .section h3 { color: #4CAF50; font-weight: bold; margin-bottom: 10px; border-bottom: 2px solid #4CAF50; padding-bottom: 5px; }
        p, ul { font-size: 14px; line-height: 1.6; }
        .table { width: 100%; border-collapse: collapse; margin: 15px 0; }
        .table th, .table td { padding: 10px; border: 1px solid #ddd; text-align: left; }
        .table th { background: #4CAF50; color: white; }
        .box h3 { background: #4CAF50; color: white; padding: 10px; margin: -15px -15px 10px -15px; border-radius: 8px 8px 0 0; }
    </style>
    <title>Project Charter</title>
</head>
<body>
    <div class="header"><h1>AI Project Management</h1><h2>Project Charter</h2></div>
    <div class="section box"><h3>Project Overview</h3>
        <p><strong>Project Name:</strong> AI Enhancement Project</p>
        <p><strong>Start/End:</strong> Jan 2024 - Dec 2024</p>
        <p><strong>Authorization Date:</strong> Jan 1, 2024</p>
    </div>
    <div class="section box"><h3>Business Case and Objectives</h3>
        <p><strong>Problem:</strong> Improve AI efficiency for client services.</p>
        <p><strong>Goals:</strong> Enhance algorithms, reduce response time by 30%.</p>
        <p><strong>Benefits:</strong> Faster processing, improved satisfaction.</p>
        <p><strong>Alignment:</strong> Digital transformation.</p>
    </div>
    <div class="section box"><h3>Stakeholder Information</h3>
        <p><strong>Register:</strong> John Doe (Manager), Jane Smith (Developer)</p>
        <p><strong>Roles:</strong> John oversees; Jane handles AI dev.</p>
        <p><strong>Communication:</strong> Weekly Zoom, daily emails.</p>
    </div>
    <div class="section box"><h3>Project Scope</h3>
        <p><strong>Scope:</strong> Develop AI tools for analysis.</p>
        <p><strong>Deliverables:</strong> AI system, Training materials.</p>
        <p><strong>Constraints:</strong> Budget, 12 months.</p>
    </div>
    <div class="section box"><h3>Risk Assessment</h3>
        <table class="table">
            <tr><th>Description</th><th>Mitigation</th><th>Owner</th></tr>
            <tr><td>Data Loss</td><td>Regular backups.</td><td>John Doe</td></tr>
            <tr><td>System Failure</td><td>Extensive testing.</td><td>Jane Smith</td></tr>
        </table>
    </div>
    <div class="section box"><h3>Methodology and Tools</h3>
        <p><strong>Methodology:</strong> Agile Scrum</p>
        <p><strong>Tools:</strong> Jira, GitHub, Slack</p>
        <p><strong>Reporting:</strong> Weekly, bi-weekly sprint reviews.</p>
    </div>
    <div class="section box"><h3>Resources</h3>
        <p><strong>Human:</strong> John, Jane, AI Team</p>
        <p><strong>Physical:</strong> Workstations, Cloud Infra</p>
        <p><strong>Budget:</strong> $500,000</p>
    </div>
    <div class="section box"><h3>Timeline</h3>
        <ul>
            <li>Jan: Initiation</li>
            <li>Feb-Jul: Development</li>
            <li>Aug: Testing</li>
            <li>Dec: Closure</li>
        </ul>
    </div>
    <div class="section box"><h3>Approval and Governance</h3>
        <p><strong>Approval:</strong> Signed by John Doe</p>
        <p><strong>Sponsor:</strong> Jane Smith</p>
        <p><strong>Governance:</strong> Weekly committee reviews.</p>
    </div>
    <div class="footer"><p>AI Project Management</p></div>
</body>
</html>
"""

# Generate the PDF
weasyprint.HTML(string=html_content).write_pdf("AI_Enhancement_Project_Charter_Optimized.pdf")

# Output file path
"AI_Enhancement_Project_Charter_Optimized.pdf"
# Out:
# DEBUG:fontTools.ttLib.ttFont:Reading 'maxp' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'maxp' table
# DEBUG:fontTools.subset.timer:Took 0.006s to load 'maxp'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'maxp'
# INFO:fontTools.subset:maxp pruned
# DEBUG:fontTools.ttLib.ttFont:Reading 'cmap' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'cmap' table
# DEBUG:fontTools.ttLib.ttFont:Reading 'post' table from disk
# DEBUG:fontTools.ttLib.ttFont:Decompiling 'post' table
# DEBUG:fontTools.subset.timer:Took 0.012s to load 'cmap'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'cmap'
# INFO:fontTools.subset:cmap pruned
# INFO:fontTools.subset:fpgm dropped
# INFO:fontTools.subset:prep dropped
# INFO:fontTools.subset:cvt  dropped
# INFO:fontTools.subset:kern dropped
# DEBUG:fontTools.subset.timer:Took 0.000s to load 'post'
# DEBUG:fontTools.subset.timer:Took 0.000s to prune 'post'
# INFO:fontTools.subset:post pruned
# INFO:fontTools.subset:GPOS dropped
# ...

# %%
from google.colab import files
files.download('AI_Enhancement_Project_Charter_Optimized.pdf')

# %%
# !pip install reportlab
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 17.9 MB/s eta 0:00:00
# ...
